# %%
import random
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import os 
import numpy as np
from PIL import Image

# %%
dota_dataset_path = "../../datasets/dota"
os.path.exists(dota_dataset_path)
# Out:
# True

# %%
from test_dota_bboxes import visualize_dota_samples_with_bboxes
visualize_dota_samples_with_bboxes(dota_dataset_path, split="train", num_samples=4)

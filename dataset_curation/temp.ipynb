# %%
from visualize_unified_dataset import visualize_unified_dataset

# %%
unified_dir = "./unified_dataset"
visualize_unified_dataset(unified_dir, num_samples=4)
# Out:
# ...
# Visualizing Unified Dataset
# ...
#
# Visualizing dota...
#
# Visualizing landcover...
# Visualizing road_extraction...
#
# Visualizing semantic_buildings...
